# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Importing data

# %%
data_13 = pd.read_excel("MATERNITY_2013.xlsx",index_col="admit_year")
data_14 = pd.read_excel("MATERNITY_2014.xlsx",index_col="admit_year")
data_15 = pd.read_excel("MATERNITY_2015.xlsx",index_col="admit_year")
data_16 = pd.read_excel("MATERNITY_2016.xlsx",index_col="admit_year")
data_17 = pd.read_excel("MATERNITY_2017.xlsx",index_col="admit_year")
data_18 = pd.read_excel("MATERNITY_2018.xlsx",index_col="admit_year")
data_19 = pd.read_excel("MATERNITY_2019.xlsx",index_col="admit_year")
data_20 = pd.read_excel("MATERNITY_2020(jan-mar).xlsx",index_col="admit_year")

# %%
scheme_B=pd.read_excel("B_MATERNITY_CLAIMS.xlsx",index_col="admit_year")
scheme_C=pd.read_excel("C_MATERNITY_MEM_CLAIMS.xlsx",index_col="admit_year")

# %% [markdown]
# # Re-Formatting the Column Headings

# %%
data_13.columns=data_13.columns.str.title()
data_14.columns=data_14.columns.str.title()
data_15.columns=data_15.columns.str.title()
data_16.columns=data_16.columns.str.title()
data_17.columns=data_17.columns.str.title()
data_18.columns=data_18.columns.str.title()
data_19.columns=data_19.columns.str.title()
data_20.columns=data_20.columns.str.title()

scheme_B.columns=scheme_B.columns.str.title()
scheme_C.columns=scheme_C.columns.str.title()

# %%
data_13.drop_duplicates()
data_14.drop_duplicates()
data_15.drop_duplicates()
data_16.drop_duplicates()
data_17.drop_duplicates()
data_18.drop_duplicates()
data_19.drop_duplicates()
data_20.drop_duplicates()

scheme_B.drop_duplicates()
scheme_C.drop_duplicates()
# Out:
#            Scheme_Code  Plan_Key  Authorization_Key  Stg_Has_Key   Member_Key  \
# admit_year
# 2013                 C       731        769805150.0    338236736  88100000214
# 2013                 C       731        768643647.0    338236740  88100000245
# 2018                 C       731        909385195.0    619395219  88100000331
# 2015                 C       731        876679347.0    542368027  88100000331
# 2018                 C       731        910010680.0    619395220  88100000331
# ...                ...       ...                ...          ...          ...
# 2019                 C       731        912810835.0    687097784  88100667705
# 2020                 C       731        913064135.0    699526385  88100668742
# 2020                 C       731        912910930.0    690643272  88100668948
# 2020                 C       731        913176090.0    702333359  88100669260
# 2020                 C       731        913063789.0    699526386  88100669882
#
#             Beneficiary_Number     Admission_Category Date_Of_Birth  \
# admit_year
# 2013                         1        Normal Delivery    1977-08-31
# 2013                         1     Caesarean Delivery    1973-01-04
# 2018                         0  Complicated Pregnancy    1983-04-29
# 2015                         0     Caesarean Delivery    1983-04-29
# 2018                         0     Caesarean Delivery    1983-04-29
# ...                        ...                    ...           ...
# 2019                         1     Caesarean Delivery    1988-02-02
# 2020                         2     Caesarean Delivery    1997-08-17
# 2020                         1        Normal Delivery    1988-03-21
# 2020                         1     Caesarean Delivery    1998-10-18
# 2020                         1        Normal Delivery    1988-06-28
#
#             Admit_Month  Age_At_Treatment  ... Pathology_Amt  Pharmacy_Amt  \
# admit_year                                 ...
# 2013             201304                35  ...          20.9         47.81
# 2013             201302                40  ...         769.4          0.00
# 2018             201803                34  ...        1918.9          0.00
# 2015             201508                32  ...         552.5        170.21
# 2018             201803                34  ...        3617.0        377.22
# ...                 ...               ...  ...           ...           ...
# 2019             201911                31  ...        1848.6        251.14
# 2020             202002                22  ...         778.6        252.52
# 2020             202001                31  ...        1033.0        162.47
# 2020             202003                21  ...        1015.3        210.07
# 2020             202002                31  ...          29.8          0.00
#
#            Age_Group  Pulse_Paypoint_Code Dpm_Ind  Beneficiary_Type  \
# admit_year
# 2013         31 - 35            SMD003SYN   Group              ADUL
# 2013         36 - 40            SMD005CHE   Group              ADUL
# 2018         31 - 35            SMD011MIN   Group              MEMB
# 2015         31 - 35            SMD011MIN   Group              MEMB
# 2018         31 - 35            SMD011MIN   Group              MEMB
# ...              ...                  ...     ...               ...
# 2019         31 - 35            SMD011MIN   Group              ADUL
# 2020         21 - 25            SMD004CHE   Group              ADUL
# 2020         31 - 35            SMD003SYN   Group              ADUL
# 2020         21 - 25            SMD011MIN   Group              ADUL
# 2020         31 - 35            SMD011MIN   Group              ADUL
#
#             Plan_Name  Pmb_Eligible  Magisterial_District_Descr  Region_Descr
# admit_year
# 2013         SASOLMED             Y                     SECUNDA    MPUMALANGA
# 2013         SASOLMED             Y              VANDERBIJLPARK       GAUTENG
# 2018         SASOLMED             Y                   MAFATSANA       GAUTENG
# 2015         SASOLMED             N                   MAFATSANA       GAUTENG
# 2018         SASOLMED             Y                   MAFATSANA       GAUTENG
# ...               ...           ...                         ...           ...
# 2019         SASOLMED             Y                     SECUNDA    MPUMALANGA
# 2020         SASOLMED             Y                  STANDERTON    MPUMALANGA
# 2020         SASOLMED             Y                  EMBALENHLE    MPUMALANGA
# 2020         SASOLMED             Y                      ERMELO    MPUMALANGA
# 2020         SASOLMED             Y                  STANDERTON    MPUMALANGA
#
# [12209 rows x 30 columns]

# %%
data_19
# Out:
#             Authorization_Key  Stg_Has_Key   Member_Key  Beneficiary_Number  \
# admit_year
# 2019              912484206.0    683782734   2000111124                   1
# 2019              911918372.0    671047732   2000165321                   2
# 2019              912205082.0    671047733   2000165321                   2
# 2019              912263325.0    673191181   2000183035                   3
# 2019              912278769.0    670892400   2000302160                   7
# ...                       ...          ...          ...                 ...
# 2019              912188347.0    674298224  47900981282                   0
# 2019              912863548.0    687973948  47900982391                   2
# 2019              912735146.0    683193997  47900984540                   2
# 2019              912916399.0    691219849  47900987592                   1
# 2019              912860373.0    688128272  47900987592                   1
#
#                                       Admission_Category Date_Of_Birth  \
# admit_year
# 2019                                  Caesarean Delivery    1986-06-27
# 2019                               Complicated Pregnancy    2001-09-30
# 2019                               Complicated Pregnancy    2001-09-30
# 2019                                  Caesarean Delivery    1995-05-01
# 2019                                  Caesarean Delivery    1977-10-30
# ...                                                  ...           ...
# 2019                                     Normal Delivery    1994-06-10
# 2019        Newborn - Complications/Premature baby major    2019-11-17
# 2019        Newborn - Complications/Premature baby minor    2019-10-21
# 2019                                  Caesarean Delivery    1997-01-30
# 2019                               Complicated Pregnancy    1997-01-30
#
#             Admit_Month  Age_At_Treatment Patient_Gender  Claim_Tariff_Code  \
# admit_year
# 2019             201910                33              F              97812
# 2019             201904                17              F              57004
# 2019             201906                17              F              57004
# 2019             201907                24              F              57012
# 2019             201907                41              F              58273
# ...                 ...               ...            ...                ...
# 2019             201907                25              F              58004
# 2019             201911                 0              M              58216
# 2019             201910                 0              M              58005
# 2019             201912                22              F              97369
# 2019             201912                22              F              97647
#
#             ... Hosp_Benefit_Amt  Provider_Amt Radiology_Amt  Pathology_Amt  \
# admit_year  ...
# 2019        ...         30446.00       8177.55          0.00        5299.90
# 2019        ...          2738.60           NaN          0.00           0.00
# 2019        ...          3530.80           NaN          0.00           0.00
# 2019        ...         27679.66       4307.84          0.00         186.40
# 2019        ...         33195.73      14950.24          0.00         831.70
# ...         ...              ...           ...           ...            ...
# 2019        ...         24364.01       5099.24          0.00        1193.30
# 2019        ...        147863.29      13309.90       4809.64        4176.61
# 2019        ...         10565.01       2482.14          0.00        1505.04
# 2019        ...         33146.00       4204.49          0.00        1112.10
# 2019        ...          7267.40       1938.60          0.00         477.90
#
#             Pharmacy_Amt     Dpm_Ind  Age_Group  Beneficiary_Type  \
# admit_year
# 2019                 0.0       Group    31 - 35              ADUL
# 2019                 0.0       Group    16 - 20              CHIL
# 2019                 0.0       Group    16 - 20              CHIL
# 2019                 0.0       Group    21 - 25              ADUL
# 2019                 0.0       Group    41 - 45              ADUL
# ...                  ...         ...        ...               ...
# 2019                 0.0       Group    21 - 25              MEMB
# 2019                 0.0  Individual          0               NaN
# 2019                 0.0  Individual          0               NaN
# 2019               380.0  Individual    21 - 25              ADUL
# 2019                 0.0  Individual    21 - 25              ADUL
#
#             Magisterial_District_Descr  Region_Descr
# admit_year
# 2019                       GROBLERSDAL       LIMPOPO
# 2019                           TEMBISA       GAUTENG
# 2019                           TEMBISA       GAUTENG
# 2019                            LETABA       LIMPOPO
# 2019                             ALICE  EASTERN CAPE
# ...                                ...           ...
# 2019                         TSHIAWELO       GAUTENG
# 2019                         GERMISTON       GAUTENG
# 2019                         CENTURION       GAUTENG
# 2019                        MIDDELBURG    MPUMALANGA
# 2019                        MIDDELBURG    MPUMALANGA
#
# [13882 rows x 25 columns]

# %%
scheme_A=pd.concat(objs=[data_13,data_14,data_15,data_16,data_17,data_18,data_19])

# %%
scheme_A
# Out:
#            Scheme_Code  Plan_Key  Authorization_Key  Stg_Has_Key   Member_Key  \
# admit_year
# 2013               BON      20.0        769500425.0    426069354   2000134527
# 2013               BON      20.0        769252214.0    425810854   2000141125
# 2013               BON      20.0        770333964.0    426326697   2000149969
# 2013               BON      20.0        769012710.0    337573074   2000156110
# 2013               BON      20.0        769315294.0    337573075   2000156110
# ...                ...       ...                ...          ...          ...
# 2019               NaN       NaN        912188347.0    674298224  47900981282
# 2019               NaN       NaN        912863548.0    687973948  47900982391
# 2019               NaN       NaN        912735146.0    683193997  47900984540
# 2019               NaN       NaN        912916399.0    691219849  47900987592
# 2019               NaN       NaN        912860373.0    688128272  47900987592
#
#             Beneficiary_Number                            Admission_Category  \
# admit_year
# 2013                         2                         Complicated Pregnancy
# 2013                         2                            Caesarean Delivery
# 2013                         5                            Caesarean Delivery
# 2013                         2                               Normal Delivery
# 2013                         3  Newborn - Complications/Premature baby major
# ...                        ...                                           ...
# 2019                         0                               Normal Delivery
# 2019                         2  Newborn - Complications/Premature baby major
# 2019                         2  Newborn - Complications/Premature baby minor
# 2019                         1                            Caesarean Delivery
# 2019                         1                         Complicated Pregnancy
#
#            Date_Of_Birth  Admit_Month  Age_At_Treatment  ... Pathology_Amt  \
# admit_year                                               ...
# 2013          1968-01-09       201304                45  ...        141.10
# 2013          1984-05-16       201304                28  ...          0.00
# 2013          1994-11-14       201302                18  ...         60.80
# 2013          1994-05-05       201303                18  ...       2463.20
# 2013          2013-03-07       201303                 0  ...          0.00
# ...                  ...          ...               ...  ...           ...
# 2019          1994-06-10       201907                25  ...       1193.30
# 2019          2019-11-17       201911                 0  ...       4176.61
# 2019          2019-10-21       201910                 0  ...       1505.04
# 2019          1997-01-30       201912                22  ...       1112.10
# 2019          1997-01-30       201912                22  ...        477.90
#
#            Pharmacy_Amt Age_Group  Pulse_Paypoint_Code     Dpm_Ind  \
# admit_year
# 2013                0.0   41 - 45            BON004KIM       Group
# 2013                0.0   26 - 30            BON019KHG       Group
# 2013                0.0   16 - 20            BON004QUE       Group
# 2013                0.0   16 - 20            BON033GDE       Group
# 2013                0.0         0            BON033GDE       Group
# ...                 ...       ...                  ...         ...
# 2019                0.0   21 - 25                  NaN       Group
# 2019                0.0         0                  NaN  Individual
# 2019                0.0         0                  NaN  Individual
# 2019              380.0   21 - 25                  NaN  Individual
# 2019                0.0   21 - 25                  NaN  Individual
#
#             Beneficiary_Type        Plan_Name  Pmb_Eligible  \
# admit_year
# 2013                    ADUL  STANDARD OPTION             Y
# 2013                    ADUL  STANDARD OPTION             Y
# 2013                    CHIL  STANDARD OPTION             Y
# 2013                    CHIL  STANDARD OPTION             Y
# 2013                     NaN  STANDARD OPTION             Y
# ...                      ...              ...           ...
# 2019                    MEMB              NaN           NaN
# 2019                     NaN              NaN           NaN
# 2019                     NaN              NaN           NaN
# 2019                    ADUL              NaN           NaN
# 2019                    ADUL              NaN           NaN
#
#             Magisterial_District_Descr   Region_Descr
# admit_year
# 2013                         KIMBERLEY  NORTHERN CAPE
# 2013                          ISIPINGO  KWAZULU-NATAL
# 2013                        QUEENSTOWN   EASTERN CAPE
# 2013                          MAMELODI        GAUTENG
# 2013                          MAMELODI        GAUTENG
# ...                                ...            ...
# 2019                         TSHIAWELO        GAUTENG
# 2019                         GERMISTON        GAUTENG
# 2019                         CENTURION        GAUTENG
# 2019                        MIDDELBURG     MPUMALANGA
# 2019                        MIDDELBURG     MPUMALANGA
#
# [100869 rows x 30 columns]

# %%
all_schemes=pd.concat(objs=[scheme_A,scheme_B,scheme_C],keys=["Scheme_A", "Scheme_B", "Scheme_C"])

# %%
all_schemes
# Out:
#                     Scheme_Code  Plan_Key  Authorization_Key  Stg_Has_Key  \
#          admit_year
# Scheme A 2013               BON      20.0        769500425.0    426069354
#          2013               BON      20.0        769252214.0    425810854
#          2013               BON      20.0        770333964.0    426326697
#          2013               BON      20.0        769012710.0    337573074
#          2013               BON      20.0        769315294.0    337573075
# ...                         ...       ...                ...          ...
# Scheme_C 2019                 C     731.0        912810835.0    687097784
#          2020                 C     731.0        913064135.0    699526385
#          2020                 C     731.0        912910930.0    690643272
#          2020                 C     731.0        913176090.0    702333359
#          2020                 C     731.0        913063789.0    699526386
#
#                       Member_Key  Beneficiary_Number  \
#          admit_year
# Scheme A 2013         2000134527                   2
#          2013         2000141125                   2
#          2013         2000149969                   5
#          2013         2000156110                   2
#          2013         2000156110                   3
# ...                          ...                 ...
# Scheme_C 2019        88100667705                   1
#          2020        88100668742                   2
#          2020        88100668948                   1
#          2020        88100669260                   1
#          2020        88100669882                   1
#
#                                                Admission_Category  \
#          admit_year
# Scheme A 2013                               Complicated Pregnancy
#          2013                                  Caesarean Delivery
#          2013                                  Caesarean Delivery
#          2013                                     Normal Delivery
#          2013        Newborn - Complications/Premature baby major
# ...                                                           ...
# Scheme_C 2019                                  Caesarean Delivery
#          2020                                  Caesarean Delivery
#          2020                                     Normal Delivery
#          2020                                  Caesarean Delivery
#          2020                                     Normal Delivery
#
#                     Date_Of_Birth  Admit_Month  Age_At_Treatment  ...  \
#          admit_year                                               ...
# Scheme A 2013          1968-01-09       201304                45  ...
#          2013          1984-05-16       201304                28  ...
#          2013          1994-11-14       201302                18  ...
#          2013          1994-05-05       201303                18  ...
#          2013          2013-03-07       201303                 0  ...
# ...                           ...          ...               ...  ...
# Scheme_C 2019          1988-02-02       201911                31  ...
#          2020          1997-08-17       202002                22  ...
#          2020          1988-03-21       202001                31  ...
#          2020          1998-10-18       202003                21  ...
#          2020          1988-06-28       202002                31  ...
#
#                     Pathology_Amt Pharmacy_Amt Age_Group  Pulse_Paypoint_Code  \
#          admit_year
# Scheme A 2013               141.1         0.00   41 - 45            BON004KIM
#          2013                 0.0         0.00   26 - 30            BON019KHG
#          2013                60.8         0.00   16 - 20            BON004QUE
#          2013              2463.2         0.00   16 - 20            BON033GDE
#          2013                 0.0         0.00         0            BON033GDE
# ...                           ...          ...       ...                  ...
# Scheme_C 2019              1848.6       251.14   31 - 35            SMD011MIN
#          2020               778.6       252.52   21 - 25            SMD004CHE
#          2020              1033.0       162.47   31 - 35            SMD003SYN
#          2020              1015.3       210.07   21 - 25            SMD011MIN
#          2020                29.8         0.00   31 - 35            SMD011MIN
#
#                     Dpm_Ind  Beneficiary_Type        Plan_Name  Pmb_Eligible  \
#          admit_year
# Scheme A 2013         Group              ADUL  STANDARD OPTION             Y
#          2013         Group              ADUL  STANDARD OPTION             Y
#          2013         Group              CHIL  STANDARD OPTION             Y
#          2013         Group              CHIL  STANDARD OPTION             Y
#          2013         Group               NaN  STANDARD OPTION             Y
# ...                     ...               ...              ...           ...
# Scheme_C 2019         Group              ADUL         SASOLMED             Y
#          2020         Group              ADUL         SASOLMED             Y
#          2020         Group              ADUL         SASOLMED             Y
#          2020         Group              ADUL         SASOLMED             Y
#          2020         Group              ADUL         SASOLMED             Y
#
#                      Magisterial_District_Descr   Region_Descr
#          admit_year
# Scheme A 2013                         KIMBERLEY  NORTHERN CAPE
#          2013                          ISIPINGO  KWAZULU-NATAL
#          2013                        QUEENSTOWN   EASTERN CAPE
#          2013                          MAMELODI        GAUTENG
#          2013                          MAMELODI        GAUTENG
# ...                                         ...            ...
# Scheme_C 2019                           SECUNDA     MPUMALANGA
#          2020                        STANDERTON     MPUMALANGA
#          2020                        EMBALENHLE     MPUMALANGA
#          2020                            ERMELO     MPUMALANGA
#          2020                        STANDERTON     MPUMALANGA
#
# [131340 rows x 30 columns]

# %%
excel_file = pd.ExcelWriter("All_Schemes_Data.xlsx")

# %%
all_schemes.to_excel(excel_file,sheet_name="Sheet1")

# %%
excel_file.save()
